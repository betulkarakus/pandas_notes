# %% [markdown]
# # Pandas Notları

# %%
import pandas as pd

# %%
df = pd.read_csv("AdvancedHousePricing.csv", index_col="Id")

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### DataFrames practice

# %% [markdown]
# ##### Activities

# %% [markdown]
# How many elements does this dataframe have?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# What is the 'MSSubClass' value of the 56(index)?

# %%
#df.loc[INDEX, COLUMNS]

# %%
df.loc[56] #It is entered the index number.
# Don't forget to use "" if the index is string.
# loc brings the row values in that index.
# Out:
# MSSubClass           20
# MSZoning             RL
# LotFrontage       100.0
# LotArea           10175
# Street             Pave
#                   ...
# MoSold                7
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        180500
# Name: 56, Length: 80, dtype: object

# %% [markdown]
# What is the highest possible 'LotArea' value of an Id(index)?

# %%
df["LotArea"].max()
# Out:
# 215245

# %%
df.max()
#the max statistical methoh computed for the whole dataframe 
# It is valid only dataframe columns that have all numerical value

# %%
df.describe()
# summary statistics of all numeric columns
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %% [markdown]
# Which of the following 'Id' have a 'MSSubClass' of 60 and a 'LotArea' of 11250?

# %%
# It is put possible Ids to observe and pick the wanted one.
df.loc[[
    2,
    45,
    68,
    21,
    3
]]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 45          20       RL         70.0     7945   Pave   NaN      Reg
# 68          20       RL         72.0    10665   Pave   NaN      IR1
# 21          60       RL        101.0    14215   Pave   NaN      IR1
# 3           60       RL         68.0    11250   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 45         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 68         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 21         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Winner 'Id' is 3. Yay!!!

# %%
df.loc[[
    2,
    45,
    68,
    21,
    3
], "LotArea"] #In this way, it can be seen particular column values for multiple indexes.
# Out:
# Id
# 2      9600
# 45     7945
# 68    10665
# 21    14215
# 3     11250
# Name: LotArea, dtype: int64

# %% [markdown]
# What is the highest possible length of a 'LotFrontage'?

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %% [markdown]
# What is the 'LotFrontage' with the value of 313.0?

# %%
df.sort_values(by=["LotFrontage"], ascending=False)
# We sorted from largest to smallest by using ascending=False in a numerical column of our choice.
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1299          60       RL        313.0    63887   Pave   NaN      IR3
# 935           20       RL        313.0    27650   Pave   NaN      IR2
# 1128          20       RL        182.0    14572   Pave   NaN      IR3
# 198           75       RL        174.0    25419   Pave   NaN      Reg
# 232           60       RL        174.0    15138   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1430          20       RL          NaN    12546   Pave   NaN      IR1
# 1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1447          20       RL          NaN    26142   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
#It does not work for this datadframe??
for row in df:
    if row["MSSubClass"] == 20:
        print(row)

# %%
df.loc[df["LotFrontage"] == 313.0]
# This is the first idea of conditional selection in pandas.
# By using boolean values, we take up less space in memory compared to loops.
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 935           20       RL        313.0    27650   Pave   NaN      IR2
# 1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 935          HLS    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1299         Bnk    AllPub    Corner  ...      480     Gd   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 935        0     11    2008        WD         Normal     242000
# 1299       0      1    2008       New        Partial     160000
#
# [2 rows x 80 columns]

# %%
(df["LotFrontage"] == 313.0)
# Actually, this operation returns a Boolean array.
# Out:
# Id
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# 1460    False
# Name: LotFrontage, Length: 1460, dtype: bool

# %% [markdown]
# What is the most common 'LotFrontage' value?

# %%
df["LotFrontage"].describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
df["LotFrontage"].mode()
# 60 is the most common value.
# Out:
# 0    60.0
# Name: LotFrontage, dtype: float64

# %%
df["LotFrontage"].value_counts().head()
# It gives value counts
# Out:
# LotFrontage
# 60.0    143
# 70.0     70
# 80.0     69
# 50.0     57
# 75.0     53
# Name: count, dtype: int64

# %%
df.loc[df["LotFrontage"] == 60.0].head(10)
# It gives top 10 values.
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 27          20       RL         60.0     7200   Pave   NaN      Reg
# 30          30       RM         60.0     6324   Pave   NaN      IR1
# 35         120       RL         60.0     7313   Pave   NaN      Reg
# 55          80       RL         60.0     7134   Pave   NaN      Reg
# 60          20       RL         60.0     7200   Pave   NaN      Reg
# 62          75       RM         60.0     7200   Pave   NaN      Reg
# 75          50       RM         60.0     5790   Pave   NaN      Reg
# 80          50       RM         60.0    10440   Pave  Grvl      Reg
# 90          20       RL         60.0     8070   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                  ...
# 4          Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# ...

# %%
df.loc[df["LotFrontage"] == 60.0].sample(10)
# It gives randomly 10 values.
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 726           20       RL         60.0     6960   Pave   NaN      Reg
# 1225          60       RL         60.0    15384   Pave   NaN      IR1
# 1394         190       RM         60.0    10800   Pave  Pave      Reg
# 1378          50       RL         60.0    10998   Pave  Grvl      Reg
# 1093          50       RL         60.0     8400   Pave   NaN      Reg
# 195           20       RL         60.0     7180   Pave   NaN      IR1
# 90            20       RL         60.0     8070   Pave   NaN      Reg
# 1399          50       RL         60.0     7200   Pave   NaN      Reg
# 1293          70       RM         60.0     6600   Pave   NaN      Reg
# 1145         190       RL         60.0    12180   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %% [markdown]
# What is the smallest 'MSSubClass' with the 'LotFrontage' value 60.0?

# %%
df.loc[df["LotFrontage"] == 60.0].sort_values(by="MSSubClass")
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1437          20       RL         60.0     9000   Pave   NaN      Reg
# 27            20       RL         60.0     7200   Pave   NaN      Reg
# 183           20       RL         60.0     9060   Pave   NaN      Reg
# 157           20       RL         60.0     7200   Pave   NaN      Reg
# 1315          20       RL         60.0     8190   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 1267         190       RM         60.0    10120   Pave   NaN      IR1
# 636          190       RH         60.0    10896   Pave  Pave      Reg
# 714          190       RL         60.0     9873   Pave   NaN      Reg
# 521          190       RL         60.0    10800   Pave  Grvl      Reg
# 1417         190       RM         60.0    11340   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df.loc[df["LotFrontage"] == 60.0, "MSSubClass"].min()
# Out:
# 20

# %%
df.loc[
    (df["LotFrontage"] == 60.0) &
    (df["MSSubClass"] == 20)
]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 27            20       RL         60.0     7200   Pave   NaN      Reg
# 60            20       RL         60.0     7200   Pave   NaN      Reg
# 90            20       RL         60.0     8070   Pave   NaN      Reg
# 91            20       RL         60.0     7200   Pave   NaN      Reg
# 157           20       RL         60.0     7200   Pave   NaN      Reg
# 183           20       RL         60.0     9060   Pave   NaN      Reg
# 195           20       RL         60.0     7180   Pave   NaN      IR1
# 282           20       FV         60.0     7200   Pave  Pave      Reg
# 342           20       RH         60.0     8400   Pave   NaN      Reg
# 382           20       FV         60.0     7200   Pave  Pave      Reg
# 397           20       RL         60.0     7200   Pave   NaN      Reg
# 463           20       RL         60.0     8281   Pave   NaN      IR1
# ...

# %% [markdown]
# Create a column 'Ratio', which represents the 'LotFrontage Ratio' of a house. LotFrontage/MSSubClass (I made it up, it does not mean anything.)

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df["Ratio"] = df["LotFrontage"] / df["MSSubClass"]

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolQC Fence MiscFeature MiscVal  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...    NaN   NaN         NaN       0
# 2          Lvl    AllPub       FR2  ...    NaN   NaN         NaN       0
# 3          Lvl    AllPub    Inside  ...    NaN   NaN         NaN       0
# 4          Lvl    AllPub    Corner  ...    NaN   NaN         NaN       0
# 5          Lvl    AllPub       FR2  ...    NaN   NaN         NaN       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice     Ratio
# Id
# ...

# %% [markdown]
# What is the maximum value of 'Ratio'?

# %%
df["Ratio"].max()
# Out:
# 15.65

# %% [markdown]
# What "LotFrontage" value is the one with the highest 'Ratio'?

# %%
df.sort_values(by="Ratio", ascending=False).head()
# By default, values are sorting in ascending mode.
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 935           20       RL        313.0    27650   Pave   NaN      IR2
# 1128          20       RL        182.0    14572   Pave   NaN      IR3
# 314           20       RL        150.0   215245   Pave   NaN      IR3
# 172           20       RL        141.0    31770   Pave   NaN      IR1
# 278           20       RL        140.0    19138   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolQC Fence MiscFeature MiscVal  \
# Id                                    ...
# 935          HLS    AllPub    Inside  ...    NaN   NaN         NaN       0
# 1128         Lvl    AllPub    Corner  ...    NaN   NaN         NaN       0
# 314          Low    AllPub    Inside  ...    NaN   NaN         NaN       0
# 172          Lvl    AllPub    Corner  ...    NaN   NaN         NaN       0
# 278          Lvl    AllPub    Corner  ...    NaN   NaN         NaN       0
#
# ...

# %%
df.loc[df["Ratio"] == df["Ratio"].max()]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 935          20       RL        313.0    27650   Pave   NaN      IR2
#
#     LandContour Utilities LotConfig  ... PoolQC Fence MiscFeature MiscVal  \
# Id                                   ...
# 935         HLS    AllPub    Inside  ...    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice  Ratio
# Id
# 935     11   2008        WD         Normal     242000  15.65
#
# [1 rows x 81 columns]

# %% [markdown]
# How many words have a 'Ratio' of 4?

# %%
df["Ratio"].value_counts()
# Answer is 36 (4.000000)
# Out:
# Ratio
# 1.200000    43
# 3.500000    40
# 3.000000    37
# 4.000000    36
# 1.000000    35
#             ..
# 0.750000     1
# 1.483333     1
# 6.700000     1
# 4.600000     1
# 5.450000     1
# Name: count, Length: 309, dtype: int64

# %%
df.loc[df["Ratio"] == 4].head()
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2            20       RL         80.0     9600   Pave   NaN      Reg
# 84           20       RL         80.0     8892   Pave   NaN      IR1
# 136          20       RL         80.0    10400   Pave   NaN      Reg
# 174          20       RL         80.0    10197   Pave   NaN      IR1
# 201          20       RM         80.0     8546   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig  ... PoolQC  Fence MiscFeature MiscVal  \
# Id                                   ...
# 2           Lvl    AllPub       FR2  ...    NaN    NaN         NaN       0
# 84          Lvl    AllPub    Inside  ...    NaN    NaN         NaN       0
# 136         Lvl    AllPub    Inside  ...    NaN  MnPrv         NaN       0
# 174         Lvl    AllPub    Inside  ...    NaN    NaN         NaN       0
# 201         Lvl    AllPub    Corner  ...    NaN    NaN         NaN       0
#
# ...

# %%
df.loc[df["Ratio"] == 4].shape
# Out:
# (36, 81)

# %%
#Query Method
df.query("Ratio == 4").shape
# Out:
# (36, 81)

# %% [markdown]
# What is the maximum value of all the 'LotFrontage' values with a 'Ratio' of 4?

# %%
df.query("Ratio == 4").sort_values(by="LotFrontage", ascending=False).head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1062          30  C (all)        120.0    18000   Grvl   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 136           20       RL         80.0    10400   Pave   NaN      Reg
# 84            20       RL         80.0     8892   Pave   NaN      IR1
# 174           20       RL         80.0    10197   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolQC  Fence MiscFeature MiscVal  \
# Id                                    ...
# 1062         Low    AllPub    Inside  ...    NaN    NaN        Shed     560
# 2            Lvl    AllPub       FR2  ...    NaN    NaN         NaN       0
# 136          Lvl    AllPub    Inside  ...    NaN  MnPrv         NaN       0
# 84           Lvl    AllPub    Inside  ...    NaN    NaN         NaN       0
# 174          Lvl    AllPub    Inside  ...    NaN    NaN         NaN       0
#
# ...

# %%
df.loc[df["Ratio"] == 4, "LotFrontage"].max()
# Out:
# 120.0

# %% [markdown]
# Of those words with the 'LotFrontage' value is 60.0, what is the smallest 'MSSubClass' value found?

# %%
df.query("LotFrontage == 60.0")
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 27            20       RL         60.0     7200   Pave   NaN      Reg
# 30            30       RM         60.0     6324   Pave   NaN      IR1
# 35           120       RL         60.0     7313   Pave   NaN      Reg
# 55            80       RL         60.0     7134   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 1429          30       RM         60.0     7200   Pave   NaN      Reg
# 1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1451          90       RL         60.0     9000   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolQC  Fence MiscFeature MiscVal  \
# Id                                    ...
# ...

# %%
df.query("LotFrontage == 60.0").sort_values(by="MSSubClass")
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1437          20       RL         60.0     9000   Pave   NaN      Reg
# 27            20       RL         60.0     7200   Pave   NaN      Reg
# 183           20       RL         60.0     9060   Pave   NaN      Reg
# 157           20       RL         60.0     7200   Pave   NaN      Reg
# 1315          20       RL         60.0     8190   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 1267         190       RM         60.0    10120   Pave   NaN      IR1
# 636          190       RH         60.0    10896   Pave  Pave      Reg
# 714          190       RL         60.0     9873   Pave   NaN      Reg
# 521          190       RL         60.0    10800   Pave  Grvl      Reg
# 1417         190       RM         60.0    11340   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolQC  Fence MiscFeature MiscVal  \
# Id                                    ...
# ...

# %%
df["MSSubClass"].describe()
# Out:
# count    1460.000000
# mean       56.897260
# std        42.300571
# min        20.000000
# 25%        20.000000
# 50%        50.000000
# 75%        70.000000
# max       190.000000
# Name: MSSubClass, dtype: float64

# %% [markdown]
# *Find the all 'Id's with 'MSSubClass'> avg MSSubClass

# %%
MSSubClass_mean = df["MSSubClass"].mean()
MSSubClass_mean
# Out:
# 56.897260273972606

# %%
df.query("'MSSubClass' > 56") # dont forget inner quote!!!
# IT does not work for this data

# %%
df.query("'MSSubClass' > @MSSubClass_mean") # using @ is essential.
# It does not work either.

# %% [markdown]
# 33'26''

# %% [markdown]
# ### Filtering and sorting with Pokemon data
